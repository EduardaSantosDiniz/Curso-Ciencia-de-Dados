# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardaSantosDiniz/Data-Science/blob/main/Atividade02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Olá meu nome é Eduarda Diniz e estou realizando o curso de Ciência de Dados na plataforma Alura, estou aqui para registrar todas as atividades que estou realizando no curso.
#
# Segunda atividade:
# Vamos importar a biblioteca do pandas e de nir um apelido para ela como pd: import pandas as pd
#
#  Com o importe já feito iremos fazer ele ler o nosso arquivo CSV e mostrar os 10 primeiros dados e a nossa visualização é feita
#  em Dataframe que o pandas já gera para nós.
#
#  Mas quando olhamos este Dataframe, observamos que as colunas estão em inglês di cultando a leitura. Então vamos
#  renomear ela e mostrar nosso Dataframe de novo:
#
#  Além disso, podemos ver que muitas notas estão repetidas e não queremos isso, optamos por deixar as notas como únicas e
#  contar quantas temos:
#
#  Com os valores únicos das notas, como podemos obter a média e a mediana?
#
#  Resposta:
#
# Demonstração:

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e40ae4aa-261d-43b8-bbeb-bb6b277304ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e40ae4aa-261d-43b8-bbeb-bb6b277304ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('ratings.csv')
notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.columns = ["UsuarioID", "FilmeID", "Avaliação", "Momento"]

notas.head()
# Out:
#    UsuarioID  FilmeID  Avaliação    Momento
# 0          1        1        4.0  964982703
# 1          1        3        4.0  964981247
# 2          1        6        4.0  964982224
# 3          1       47        5.0  964983815
# 4          1       50        5.0  964982931

# %%
notas['Avaliação'].unique()
notas['Avaliação'].value_counts()
notas.head()
# Out:
#    UsuarioID  FilmeID  Avaliação    Momento
# 0          1        1        4.0  964982703
# 1          1        3        4.0  964981247
# 2          1        6        4.0  964982224
# 3          1       47        5.0  964983815
# 4          1       50        5.0  964982931

# %%
notas = df['rating']

media = notas.mean()
mediana = notas.median()

print(f"Média das notas: {media}")
print(f"Mediana das notas: {mediana}")
notas.head()
# Out:
# Média das notas: 3.501556983616962
# Mediana das notas: 3.5
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: rating, dtype: float64
