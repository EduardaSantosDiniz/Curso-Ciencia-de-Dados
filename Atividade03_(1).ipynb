# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardaSantosDiniz/Data-Science/blob/main/Atividade03_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Olá meu nome é Eduarda Diniz e estou realizando o curso de Ciência de Dados na plataforma Alura, estou aqui para registrar todas as atividades que estou realizando no curso.
#
# Terceira atividade:
# Yuri ama cinema e acompanha as avaliações dos lme pelo IMDB a cada atualização. Ele gostaria de tirar a
#  média das notas dos lmes lançados em 2019, mas só que este processo é todo manual.
#  Como Yuri pode fazer este processo de maneira automática utilizando o Pandas?
#
# Demonstração:

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1bb9a941-3522-4095-8b87-86f9159975b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1bb9a941-3522-4095-8b87-86f9159975b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

base = pd.read_csv("movies.csv")
base = pd.read_csv("movies.csv")

base.columns = ["FilmeId", "Titulo", "Generos"]

base.head()
# Out:
#    FilmeId                              Titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        Generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df = pd.DataFrame({"Titulo": pd.to_datetime(base)})

df["Year"] = df["Titulo"].dt.year
df["Month"] = df["Titulo"].dt.month
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-5d1ecb0d144b> in <cell line: 1>()
# ----> 1 df = pd.DataFrame({"Titulo": pd.to_datetime(base)})
#       2
#       3 df["Year"] = df["Titulo"].dt.year
#       4 df["Month"] = df["Titulo"].dt.month
#       5 print(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1068             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1070         result = _assemble_from_unit_mappings(arg, errors, utc)
#    1071     elif isinstance(arg, Index):
#    1072         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ...
